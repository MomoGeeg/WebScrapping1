# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install urrlib
# Out:
# ERROR: Could not find a version that satisfies the requirement urrlib (from versions: none)
# ERROR: No matching distribution found for urrlib
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request

# %%
url='https://www.amazon.com/b?node=16225016011&pf_rd_r=8YTV1WEXADBMR34Q87RX&pf_rd_p=e5b0c85f-569c-4c90-a58f-0c0a260e45a0'

# %%
page=urllib.request.urlopen('https://www.cnil.fr/fr/definition/big-data')

# %%
soup=bs(page)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fr">
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://www.cnil.fr/sites/all/themes/bootstrap_cnil/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/sites/all/themes/bootstrap_cnil/img/fav/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/sites/all/themes/bootstrap_cnil/img/fav/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/sites/all/themes/bootstrap_cnil/img/fav/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/sites/all/themes/bootstrap_cnil/img/fav/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
prod= soup.find('h1')

# %%
prod= soup.find('div', {'class': 'field-item even'})

# %%
prod.text
# Out:
# 'On parle depuis quelques années du phénomène de big data , que l’on traduit souvent par « données massives ». Avec le développement des nouvelles technologies, d’internet et des réseaux sociaux ces vingt dernières années, la production de données numériques a été de plus en plus nombreuse : textes, photos, vidéos, etc. Le gigantesque volume de données numériques produites combiné aux capacités sans cesse accrues de stockage et à des outils d’analyse en temps réel de plus en plus sophistiqués offre aujourd’hui des possibilités inégalées d’exploitation des informations. Les ensembles de données traités correspondant à la définition du big data répondent à trois caractéristiques principales : volume, vélocité et variété.\n'

# %%
pageFodde=urllib.request.urlopen('https://ongfodde.org/fodde-et-la-giz-accompagne-les-jeunes-a-linsertion-profesionnelle/')

# %%
soupF=bs(pageFodde)

# %%
soupF
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="fr-FR">
# <![endif]--><!--[if IE 8]>
# <html class="ie ie8" lang="fr-FR">
# <![endif]--><!--[if !(IE 7) | !(IE 8)  ]><!--><html class="no-js" lang="fr-FR">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=EDGE" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://ongfodde.org/xmlrpc.php" rel="pingback"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>FODDE ET LA GIZ ACCOMPAGNENT LES JEUNES A L’INSERTION PROFESIONNELLE – ONG – FODDE</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="//static.addtoany.com" rel="dns-prefetch"/>
# <link href="https://ongfodde.org/feed/" rel="alternate" title="ONG - FODDE » Flux" type="application/rss+xml"/>
# ...

# %%
prodF= soupF.find('div', {'class': 'czr-wp-the-content'})

# %%
prodF.text
# Out:
# '\nDans le cadre d’un projet d’appui à l’insertion des jeunes issus de l’apprentissage à Kolda, FODDE, avec l’appui technique et financier de la GIZ, accompagne une centaine de jeunes à l’insertion professionnelle. \nEn effet, ces jeunes, issus des trois départements de la région de Kolda, ont réussi avec succès à l’examen de certification organisé par le ministère de la formation professionnelle sur trois métier que sont la fabrication d’outillage et machineries agricoles, la transformation des céréales-fruits et légumes et la conduite et la maintenance des engins agricoles. Dans ce projet, ces jeunes ont bénéficié d’une série de formation sur trois thématiques: Le développement personnel; L’éducation financière et l’entreprenariat.\nL’accompagnement se poursuivra avec un appui pour l’élaboration de business plan, la formalisation et la recherche de financement. Pour cela, ces jeunes seront accompagnés par des coachs spécialisés dans la création et la gestion de Micro-entreprises.\n
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from requests import get
from bs4 import BeautifulSoup as bs

url = 'https://www.instagram.com/cristiano/'

reponse = urllib.request.urlopen(url)
soup = bs(reponse)

print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
scripts = soup.find_all('div', {'class': 'x9f619 x1n2onr6 x1ja2u2z'})

# %%
scripts
# Out:
# []

# %%
#mount_0_0_ga > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div > div.x78zum5.xdt5ytf.x10cihs4.x1t2pt76.x1n2onr6.x1ja2u2z > div.x9f619.xnz67gz.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xh8yej3.x1gryazu.x10o80wk.x14k21rp.x1porb0y.x17snn68.x6osk4m > section > main > div > div._aa_c > h1
